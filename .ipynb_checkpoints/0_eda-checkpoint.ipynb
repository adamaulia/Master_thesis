# %%
import pandas as pd 
from sklearn.impute import SimpleImputer
from catboost import CatBoostRegressor
pd.set_option("display.max_rows", 999)

# %%
df = pd.read_csv('../../data/Telecom_customer churn.csv')

# %%
df.head()
# Out:
#    rev_Mean  mou_Mean  totmrc_Mean  da_Mean  ovrmou_Mean  ovrrev_Mean  \
# 0   23.9975    219.25       22.500   0.2475         0.00          0.0
# 1   57.4925    482.75       37.425   0.2475        22.75          9.1
# 2   16.9900     10.25       16.990   0.0000         0.00          0.0
# 3   38.0000      7.50       38.000   0.0000         0.00          0.0
# 4   55.2300    570.50       71.980   0.0000         0.00          0.0
#
#    vceovr_Mean  datovr_Mean  roam_Mean  change_mou  ...  forgntvl  ethnic  \
# 0          0.0          0.0        0.0     -157.25  ...       0.0       N
# 1          9.1          0.0        0.0      532.25  ...       0.0       Z
# 2          0.0          0.0        0.0       -4.25  ...       0.0       N
# 3          0.0          0.0        0.0       -1.50  ...       0.0       U
# 4          0.0          0.0        0.0       38.50  ...       0.0       I
#
#    kid0_2  kid3_5  kid6_10  kid11_15  kid16_17  creditcd  eqpdays  Customer_ID
# ...

# %%
df_null = pd.DataFrame(df.isnull().sum()).reset_index()
df_null.columns = ['columns','value']
df_null['percentage'] = df_null['value']/df.shape[0] * 100

# %%
df_null[df_null['percentage']>0]
# Out:
#              columns  value  percentage
# 0           rev_Mean    357       0.357
# 1           mou_Mean    357       0.357
# 2        totmrc_Mean    357       0.357
# 3            da_Mean    357       0.357
# 4        ovrmou_Mean    357       0.357
# 5        ovrrev_Mean    357       0.357
# 6        vceovr_Mean    357       0.357
# 7        datovr_Mean    357       0.357
# 8          roam_Mean    357       0.357
# 9         change_mou    891       0.891
# 10        change_rev    891       0.891
# 67           avg6mou   2839       2.839
# 68           avg6qty   2839       2.839
# 69           avg6rev   2839       2.839
# 70  prizm_social_one   7388       7.388
# 71              area     40       0.040
# 72          dualband      1       0.001
# 73        refurb_new      1       0.001
# 74         hnd_price    847       0.847
# 75            phones      1       0.001
# 76            models      1       0.001
# 77        hnd_webcap  10189      10.189
# ...

# %%
df['churn'].value_counts()
# Out:
# 0    50438
# 1    49562
# Name: churn, dtype: int64

# %% [markdown]
# # data imputation

# %%
imp = SimpleImputer(missing_values=np.nan, strategy='median')
imp.fit(df['adults'].to_numpy().reshape(-1,1))
